# %%
import pandas as pd

# %%
RTH = pd.read_csv('CDK_RTH/21_MAY_RTH.csv')

# %%
RTH.columns
# Out:
# Index(['RO-NO...\n', 'BOOKED.\nDATE', 'CLOSED.\nDATE', 'DT\n', 'TECH...\nNO',
#        'LN\n', 'SEQ\nNO', 'M\n', 'HT\n', 'SC\n', 'LBR..\nTYPE', 'PAY.\nTYPE',
#        'ACTUAL.\nHOURS', 'SOLD...\nHOURS', 'SOLD......\nAMOUNT',
#        'LABOR.....\nCOST', 'OP-CODE...\n', 'DESCRIPTION..\n', 'Unnamed: 18'],
#       dtype='object')

# %%
df = RTH.dropna()

# %%
df.columns
# Out:
# Index(['RO-NO...\n', 'BOOKED.\nDATE', 'CLOSED.\nDATE', 'DT\n', 'TECH...\nNO',
#        'LN\n', 'SEQ\nNO', 'M\n', 'HT\n', 'SC\n', 'LBR..\nTYPE', 'PAY.\nTYPE',
#        'ACTUAL.\nHOURS', 'SOLD...\nHOURS', 'SOLD......\nAMOUNT',
#        'LABOR.....\nCOST', 'OP-CODE...\n', 'DESCRIPTION..\n', 'Unnamed: 18'],
#       dtype='object')

# %%
df.head()
# Out:
#   RO-NO...\n BOOKED.\nDATE CLOSED.\nDATE DT\n TECH...\nNO LN\n SEQ\nNO M\n  \
# 0     167745       06MAY21       06MAY21   S1       99999    E       5
# 2     167745       06MAY21       06MAY21   S1       99999    G       7
# 4     168575       07MAY21       13MAY21   S1       99999    D       4
# 6     168725       11MAY21       11MAY21   S1       99999    D       5   *
# 8     169041       12MAY21       12MAY21   S1       99999    D       5
#
#   HT\n SC\n LBR..\nTYPE PAY.\nTYPE  ACTUAL.\nHOURS  SOLD...\nHOURS  \
# 0   ST            ISM          ROP             0.0             0.3
# 2   ST            ISD          ROP             0.0             0.0
# 4   ST            WS4          ROP             0.0             0.0
# 6   ST            ISM          ROP             0.0            -1.0
# 8   ST            ISM          ROP             0.0             0.0
#
#    SOLD......\nAMOUNT LABOR.....\nCOST OP-CODE...\n DESCRIPTION..\n  \
# 0               30.00               15   FUEL         FUEL INDUCTIO
# 2              212.31                0   UCD          RUDYS EXPRESS
# 4              250.00                0   LOANER       LOANER VEHICL
# 6                0.00              -50   RECALL       NO PARTS AVAI
# 8                0.00                0   RECALL       RECALL PERFOR
#
#   Unnamed: 18
# 0          \r
# 2          \r
# 4          \r
# 6          \r
# 8          \r

# %%
Renamed_df = df.rename(columns={'RO-NO...\n':'RO_NO','BOOKED.\nDATE':'BOOKED', 'CLOSED.\nDATE': 'CLOSED_DATE',\
                    'TECH...\nNO':'TECH_NO','LN\n':'LINE','LBR..\nTYPE':'LABOR_TYPE',\
                    'ACTUAL.\nHOURS':'ACTUAL_HOURS', 'SOLD...\nHOURS':'SOLD-HOURS',\
                    'OP-CODE...\n':'OP_CODE', 'DESCRIPTION..\n':'DESCRIPTION'})

# %%
Scrubed_RTH = Renamed_df[['RO_NO','BOOKED','CLOSED_DATE',\
                    'TECH_NO','LINE','LABOR_TYPE','ACTUAL_HOURS','SOLD-HOURS',\
                    'OP_CODE','DESCRIPTION']]

# %%
Scrubed_RTH.head()
# Out:
#     RO_NO    BOOKED CLOSED_DATE TECH_NO LINE LABOR_TYPE  ACTUAL_HOURS  \
# 0  167745   06MAY21     06MAY21   99999    E      ISM             0.0
# 2  167745   06MAY21     06MAY21   99999    G      ISD             0.0
# 4  168575   07MAY21     13MAY21   99999    D      WS4             0.0
# 6  168725   11MAY21     11MAY21   99999    D      ISM             0.0
# 8  169041   12MAY21     12MAY21   99999    D      ISM             0.0
#
#    SOLD-HOURS      OP_CODE     DESCRIPTION
# 0         0.3   FUEL         FUEL INDUCTIO
# 2         0.0   UCD          RUDYS EXPRESS
# 4         0.0   LOANER       LOANER VEHICL
# 6        -1.0   RECALL       NO PARTS AVAI
# 8         0.0   RECALL       RECALL PERFOR

# %%
df = Scrubed_RTH.groupby('TECH_NO')['SOLD-HOURS'].sum()
df2 = pd.DataFrame(df)
df3 = df2.reset_index(inplace=False)
df3
# Out:
#      TECH_NO  SOLD-HOURS
# 0                3269.82
# 1        ***     3269.82
# 2     3   ST       32.56
# 3     4   ST       -7.50
# 4     165515      159.54
# 5     178894      258.80
# 6     188507      112.81
# 7     197655       10.26
# 8     199431      214.19
# 9     199678       63.36
# 10    201138      206.67
# 11    203659      193.60
# 12    204777       96.00
# 13    205155       54.80
# 14    206080      190.45
# 15    207992       94.80
# 16    209725      114.40
# 17    210186      127.07
# 18    210630      231.87
# 19    211250      280.20
# 20    211273      224.30
# 21    229209       29.80
# 22    229933      148.05
# 23    238941      102.00
# 24    238987      142.40
# 25    239080       98.75
# 26    239669      106.00
# 27    239726        4.70
# 28     99999        4.70

# %%
tech_list = df3['TECH_NO']
tech_list
techlist = []
for tech in tech_list:
    techlist.append(tech)
    
techlist
# Out:
# ['        ',
#  '     ***',
#  '  3   ST',
#  '  4   ST',
#  '165515',
#  '178894',
#  '188507',
#  '197655',
#  '199431',
#  '199678',
#  '201138',
#  '203659',
#  '204777',
#  '205155',
#  '206080',
#  '207992',
#  '209725',
#  '210186',
#  '210630',
#  '211250',
#  '211273',
#  '229209',
#  '229933',
#  '238941',
#  '238987',
#  '239080',
#  '239669',
#  '239726',
#  '99999']

# %%
active = df3.iloc[4:28,:]
active
# Out:
#    TECH_NO  SOLD-HOURS
# 4   165515      159.54
# 5   178894      258.80
# 6   188507      112.81
# 7   197655       10.26
# 8   199431      214.19
# 9   199678       63.36
# 10  201138      206.67
# 11  203659      193.60
# 12  204777       96.00
# 13  205155       54.80
# 14  206080      190.45
# 15  207992       94.80
# 16  209725      114.40
# 17  210186      127.07
# 18  210630      231.87
# 19  211250      280.20
# 20  211273      224.30
# 21  229209       29.80
# 22  229933      148.05
# 23  238941      102.00
# 24  238987      142.40
# 25  239080       98.75
# 26  239669      106.00
# 27  239726        4.70

# %%
newactive = active.reset_index()
newactive
# Out:
#     index TECH_NO  SOLD-HOURS
# 0       4  165515      159.54
# 1       5  178894      258.80
# 2       6  188507      112.81
# 3       7  197655       10.26
# 4       8  199431      214.19
# 5       9  199678       63.36
# 6      10  201138      206.67
# 7      11  203659      193.60
# 8      12  204777       96.00
# 9      13  205155       54.80
# 10     14  206080      190.45
# 11     15  207992       94.80
# 12     16  209725      114.40
# 13     17  210186      127.07
# 14     18  210630      231.87
# 15     19  211250      280.20
# 16     20  211273      224.30
# 17     21  229209       29.80
# 18     22  229933      148.05
# 19     23  238941      102.00
# 20     24  238987      142.40
# 21     25  239080       98.75
# 22     26  239669      106.00
# 23     27  239726        4.70

# %%
resetindex_active = newactive[['TECH_NO','SOLD-HOURS']]
resetindex_active
# Out:
#    TECH_NO  SOLD-HOURS
# 0   165515      159.54
# 1   178894      258.80
# 2   188507      112.81
# 3   197655       10.26
# 4   199431      214.19
# 5   199678       63.36
# 6   201138      206.67
# 7   203659      193.60
# 8   204777       96.00
# 9   205155       54.80
# 10  206080      190.45
# 11  207992       94.80
# 12  209725      114.40
# 13  210186      127.07
# 14  210630      231.87
# 15  211250      280.20
# 16  211273      224.30
# 17  229209       29.80
# 18  229933      148.05
# 19  238941      102.00
# 20  238987      142.40
# 21  239080       98.75
# 22  239669      106.00
# 23  239726        4.70

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
labels =[ '165515',
 '178894',
 '188507',
 '197655',
 '199431',
 '199678',
 '201138',
 '203659',
 '204777',
 '205155',
 '206080',
 '207992',
 '209725',
 '210186',
 '210630',
 '211250',
 '211273',
 '229209',
 '229933',
 '238941',
 '238987',
 '239080',
 '239669',
 '239726']
plt.figure(figsize=(10,6))
Tech=sns.barplot(x='TECH_NO', y='SOLD-HOURS', data=resetindex_active)
Tech.set_xticklabels(labels, fontsize=14, rotation=30, ha= 'right');
